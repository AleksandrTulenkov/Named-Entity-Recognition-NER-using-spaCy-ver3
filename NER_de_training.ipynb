# %%
#Import all required libraries
import random
import json
from tqdm import tqdm

import spacy
from spacy import displacy
from spacy.tokens import DocBin
from spacy.tokens import Span

from sklearn.model_selection import train_test_split

# %% [markdown]
# ***********
# ### Data preparation step
#
# Load data and convert to Spacy ver3 format

# %%
def convert_to_NER_format(input_data):
    """
    """
    spacy_NER_data = []
    labels_list = []
    for sentence in data:
        labels_list += [label[2] for label in sentence['labels']]  
        entities_dict = {'entities':[tuple(j) for j in sentence['labels']]}
        spacy_NER_data.append([sentence["text"], entities_dict])
        
    return spacy_NER_data, list(set(labels_list))

def convert_NER_data_spacy3(input_data, path_to_save):
    """
    """
    db = DocBin() # create a DocBin object
    for text, annot in tqdm(input_data):
        doc = nlp.make_doc(text) # create doc object from text
        ents = []
        for start, end, label in annot["entities"]: # add character indexes
            span = doc.char_span(start, end, label=label, alignment_mode="expand")
            if span is None:
                print("Skipping entity", label, text[start:end])
            else:
                ents.append(span)
        doc.ents = ents # label the text with the ents
        db.add(doc)
    db.to_disk(path_to_save) # save the docbin object

# %%
path_to_train_data = 'input_data.json'

with open(path_to_train_data) as json_file:
    data = json.load(json_file)

# %%
spacy_NER_data, data_labels = convert_to_NER_format(data)
TRAIN_DATA, VALID_DATA = train_test_split(spacy_NER_data, test_size=0.2, random_state=42)

# %%
nlp = spacy.blank("de") 
convert_NER_data_spacy3(TRAIN_DATA, path_to_save="./train.spacy")
convert_NER_data_spacy3(VALID_DATA, path_to_save="./valid.spacy")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 171/171 [00:00<00:00, 305.76it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 43/43 [00:00<00:00, 271.69it/s]

# %% [markdown]
# ************
# ### INIT CONFIG FILES
#
# Create config files to train models.
# Aditionally was added:
#
# - Wandb logger preferences
# - vectors lookups for large (accuracy) model

# %%
import warnings
import os
import logging

warnings.filterwarnings('ignore')

logging.getLogger("spacy_lefff").setLevel(logging.WARNING)
os.environ['WANDB_SILENT'] = 'true'

# %%
#!python -m spacy init config config_demo_acc.cfg --lang de --pipeline ner --optimize accuracy

# %%
#!python -m spacy init config config_demo_efficiency.cfg --lang de --pipeline ner --optimize efficiency

# %% [markdown]
# ************
# ### TRAIN CLI

# %%
# !python -m spacy train config_demo_efficiency.cfg --output ./ner_efficiency/training/ --paths.train train.spacy --paths.dev valid.spacy
# Out:
# [i] Using CPU
#
# =========================== Initializing pipeline ===========================
# [+] Initialized pipeline
#
# ============================= Training pipeline =============================
# [i] Pipeline: ['tok2vec', 'ner']
# [i] Initial learn rate: 0.001
#
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     62.67    0.17    0.14    0.23    0.00
#   1     200        154.03   2033.13   90.78   90.27   91.30    0.91
#   2     400        121.05    352.87   94.02   94.46   93.59    0.94
#   3     600        175.35    341.57   93.76   93.02   94.51    0.94
#   5     800        218.10    314.23   94.61   96.88   92.45    0.95
#   7    1000       4192.30    459.20   95.71   96.95   94.51    0.96
#  10    1200        147.29    123.14   96.06   97.19   94.97    0.96
#  13    1400        176.29    111.08   96.30   97.42   95.19    0.96
#  17    1600        200.99     84.53   95.32   95.00   95.65    0.95
#  22    1800        153.28     71.55   95.14   96.25   94.05    0.95
#  28    2000        159.61     61.53   94.80   95.79   93.82    0.95
#  35    2200         56.33     36.79   95.88   95.88   95.88    0.96
#  43    2400        149.97     40.48   95.59   96.94   94.28    0.96
#  52    2600         82.78     10.76   95.49   96.50   94.51    0.95
#  62    2800        144.92     18.28   95.18   95.40   94.97    0.95
#  71    3000         70.77      9.74   95.18   95.40   94.97    0.95
#
# [+] Saved pipeline to output directory
# ner_efficiency\training\model-last
# 2021-08-01 13:58:27.808814: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-01 13:58:27.808851: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# [2021-08-01 13:58:31,742] [INFO] Set up nlp object from config
# [2021-08-01 13:58:32,546] [INFO] Pipeline: ['tok2vec', 'ner']
# [2021-08-01 13:58:32,551] [INFO] Created vocabulary
# [2021-08-01 13:58:32,551] [INFO] Finished initializing nlp object
# [2021-08-01 13:58:34,439] [INFO] Initialized pipeline components: ['tok2vec', 'ner']

# %%
# !python -m spacy train config_demo_acc.cfg --output ./ner_acc/training/ --paths.train train.spacy --paths.dev valid.spacy
# Out:
# [i] Using CPU
#
# =========================== Initializing pipeline ===========================
# [+] Initialized pipeline
#
# ============================= Training pipeline =============================
# [i] Pipeline: ['tok2vec', 'ner']
# [i] Initial learn rate: 0.001
#
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     62.67    0.00    0.00    0.00    0.00
#   1     200         90.35   1562.25   91.70   93.78   89.70    0.92
#   2     400         35.55    393.02   95.56   95.02   96.11    0.96
#   3     600        405.05    394.51   93.48   91.83   95.19    0.93
#   5     800         62.10    285.57   95.16   95.82   94.51    0.95
#   7    1000        426.11    216.40   96.58   96.15   97.03    0.97
#  10    1200        206.35    243.82   94.70   95.36   94.05    0.95
#  13    1400         55.00    112.97   95.18   95.40   94.97    0.95
#  17    1600         68.92    111.45   95.19   95.19   95.19    0.95
#  22    1800         23.94     31.66   96.66   97.44   95.88    0.97
#  28    2000          5.61      3.74   96.67   97.00   96.34    0.97
#  35    2200         31.24     21.55   96.02   95.48   96.57    0.96
#  43    2400         59.68     63.79   94.79   96.01   93.59    0.95
#  52    2600        374.19    163.93   95.53   95.64   95.42    0.96
#  62    2800         94.60     86.05   95.46   97.16   93.82    0.95
#  71    3000         18.24     10.61   95.97   96.53   95.42    0.96
#  81    3200         51.83     22.55   95.84   96.74   94.97    0.96
#  90    3400         33.97     14.17   96.54   97.22   95.88    0.97
#  99    3600        166.85     85.06   96.34   96.34   96.34    0.96
#
# [+] Saved pipeline to output directory
# ner_acc\training\model-last
# 2021-08-01 14:08:46.714073: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-08-01 14:08:46.714102: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# [2021-08-01 14:08:49,238] [INFO] Set up nlp object from config
# [2021-08-01 14:08:49,681] [INFO] Pipeline: ['tok2vec', 'ner']
# [2021-08-01 14:08:49,684] [INFO] Created vocabulary
# [2021-08-01 14:08:52,140] [INFO] Added vectors: de_core_news_lg
# [2021-08-01 14:08:52,141] [INFO] Finished initializing nlp object
# [2021-08-01 14:08:55,063] [INFO] Initialized pipeline components: ['tok2vec', 'ner']

# %% [markdown]
# ***************
# ### Visualization Part

# %%
ner = spacy.load(R"model")

# %%
colour_dict = dict(zip(data_labels, 
                       ["#%06x" % random.randint(0, 0xFFFFFF) for i in range(len(data_labels))]))

# %%
for sentence, _ in VALID_DATA[10:20]:
    doc = ner(sentence)
    options = {"ents": data_labels, "colors": colour_dict}
    displacy.render(doc,jupyter=True, style = "ent", options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung RegisSTAR</br></br></br></br>Amtsgericht Rostock Aktenzeichen: HRB 10050 </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20.02.2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  21:59 Uhr</br></br>In ( ) gesetzte Angaben der Anschrift und des Geschäftszweiges erfolgen ohne Gewähr:</br>Veränderungen</br>20.02.2014</br></br>HRB 10050:Kavelstorfer Dienstleistungs- und Service-GmbH, Kavelstorf, Landweg 7, 18196 Kavelstorf.Die Gesellschafterversammlung vom 11.02.2014 hat die Änderung des Gesellschaftsvertrages in § 5 (Geschäftsführung, Vertretung), § 6 Gesellschafterversammlung), § 7 Gesellschafterbeschlüsse), § 12 (Erbfolge), § 13 (Austritt) und § 15 (Bewertung und Abfindung) beschlossen.
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geändert, nun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
# :
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geschäftsführer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# :
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grohs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fred
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Radegast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     24.02.1963
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# ;
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Heidebrecht
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Axel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hamburg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     19.06.1968
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# , jeweils einzelvertretungsberechtigt; mit der Befugnis, im Namen der Gesellschaft mit sich im eigenen Namen oder als Vertreter eines Dritten Rechtsgeschäfte abzuschließen.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung RegisSTAR</br></br></br></br>Amtsgericht Wiesbaden Aktenzeichen: HRB 10000 </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     08.08.2006
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
# Die in () gesetzten Angaben der Geschäftsanschrift und des Geschäftszweiges erfolgen ohne Gewähr.</br>Veränderungen</br>04.08.2006</br></br>Linde Aktiengesellschaft, Wiesbaden (Abraham-Lincoln-Str. 21, 65189 Wiesbaden).
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prokura
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
#
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     erloschen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
# :
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hübner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Detlef
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# , Dipl.-Wirtsch.-Ing,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wiesbaden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# .
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gesamtprokura
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
#  gemeinsam mit einem Vorstandsmitglied oder einem anderen Prokuristen beschränkt auf die Hauptniederlassung:
# <mark class="entity" style="background: #aa54c6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TITLE</span>
# </mark>
#
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Asche
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Henning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niedernhausen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20.05.1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# ;
# <mark class="entity" style="background: #aa54c6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dr.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TITLE</span>
# </mark>
#
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bücklers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maximilian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankfurt am Main
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     06.10.1967
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# ;
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Revesz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Veronika
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eschborn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22.05.1965.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung RegisSTAR</br></br></br></br>Amtsgericht Saarbrücken Aktenzeichen: HRA 61013 </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25.07.2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  12:03 Uhr</br></br>Die in () gesetzten Angaben der Geschäftsanschrift und des Unternehmensgegenstandes erfolgen ohne Gewähr.</br>Veränderungen</br>24.07.2007</br></br>Anna Bohnenberger GmbH &amp; Co. KG, Merzig (Bahnhofstraße 49 a, 66663 Merzig).Die Gesellschaft ist aufgelöst. Die Gesellschaft wird durch den Liquidator vertreten.
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bestellt als
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
#
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Liquidator
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# :
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bohnenberger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Claudia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Merzig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20.10.1967
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# , mit der Befugnis im Namen der Gesellschaft mit sich im eigenen Namen oder als Vertreter eines Dritten Rechtsgeschäfte abzuschließen.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung RegisSTAR</br></br></br></br>Amtsgericht Stuttgart Aktenzeichen: HRA 222292 </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     09.03.2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  11:47 Uhr</br></br>Die in () gesetzten Angaben der Geschäftsanschrift und des Unternehmensgegenstandes erfolgen ohne Gewähr.</br>Veränderungen</br>19.02.2007</br></br>TTS Tooltechnic Systems AG &amp; Co. KG, Wendlingen am Neckar (Wertstr. 20, 73240 Wendlingen am Neckar).
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gesamtprokura
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
#  gemeinsam mit einem persönlich haftenden Gesellschafter oder einem anderen Prokuristen:
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Schulz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Holger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nürtingen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     01.12.1965
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# ;
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wudtke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jürgen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steinenbronn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     12.07.1962.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung RegisSTAR</br></br></br></br>Amtsgericht Stuttgart Aktenzeichen: HRB 100248 </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04.08.2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  12:00 Uhr</br></br>Die in () gesetzten Angaben der Geschäftsanschrift und des Unternehmensgegenstandes erfolgen ohne Gewähr.</br>Veränderungen</br>01.08.2008</br></br>F I B R O GmbH, Weinsberg (Weidachstr. 41-43, 74189 Weinsberg).
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bestellt als
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
#
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geschäftsführer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# :
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lütkemeyer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jochen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stuttgart
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     26.07.1961.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung AUREG</br></br></br></br>Amtsgericht Frankfurt/Oder Aktenzeichen: HRA 989    </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     19.12.2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  08:17 Uhr</br></br>Für die Angaben in (), die den Unternehmensgegenstand und die Anschrift betreffen, keine Gewähr. In das Handelsregister ist folgendes eingetragen worden.</br>Veränderungen</br>14.12.2005</br></br>BDV Energieservice GmbH &amp; Co. KG, Müllrose(Gewerbeparkring 17, 15299  Müllrose).
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prokura
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# :
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nicht mehr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
#
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Prokurist
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# : 1.
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Klaus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hans-Jürgen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# . Die Gesellschaft ist aufgelöst. Die Firma ist erloschen..</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung RegisSTAR</br></br></br></br>Amtsgericht Hildesheim Aktenzeichen: HRB 101625 </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04.01.2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  03:16 Uhr</br></br>Die in () gesetzten Angaben der Geschäftsanschrift und des Unternehmensgegenstandes erfolgen ohne Gewähr.</br>Veränderungen</br>20.12.2006</br></br>A.S. Reisen GmbH, Ilsede (Gerhardstr. 41, 31241 Ilsede).
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nicht mehr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
#
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geschäftsführer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# :
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scheuten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dennis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     09.04.1980.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
#
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bestellt als
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
#
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geschäftsführerin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# :
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scheuten
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Angelika
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ilsede
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20.12.1959
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# , mit der Befugnis, im Namen der Gesellschaft mit sich im eigenen Namen oder als Vertreter eines Dritten Rechtsgeschäfte abzuschließen.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung AUREG</br></br></br></br>Amtsgericht Cottbus Aktenzeichen: GnR 226    </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15.11.2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  15:13 Uhr</br></br>Für die Angaben in (), die den Unternehmensgegenstand und die Anschrift betreffen, keine Gewähr. In das Genossenschaftsregister ist folgendes eingetragen worden.</br>Veränderungen</br>03.11.2005</br></br>Wohnungsbaugenossenschaft &quot;Am Werk&quot; e.G., Lauchhammer(Hüttenstr. 1 e, 01979  Lauchhammer-Ost).
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ausgeschieden
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
# :
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vorstand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# ; 1.
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paßkönig
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Reiner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ;
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vorstandsmitglied
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# :
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hartfiel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jörg-Dieter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     05.05.1963
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lauchhammer-Mitte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# ; mit der Befugnis Rechtsgeschäfte als Vertreter Dritter abzuschließen..</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung RegisSTAR</br></br></br></br>Amtsgericht Walsrode Aktenzeichen: HRA 120040 </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15.04.2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  12:00 Uhr</br></br>Die in () gesetzten Angaben der Geschäftsanschrift und des Unternehmensgegenstandes erfolgen ohne Gewähr.</br>Veränderungen</br>14.04.2008</br></br>Dodenhof GmbH &amp; Co.KG, Ottersberg-Posthausen (Mitteldorf 1, 28870 Ottersberg).
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gesamtprokura
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
#  gemeinsam mit einem persönlich haftenden Gesellschafter oder einem anderen Prokuristen:
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brockmann
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stefan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bremen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21.11.1968.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Öffentliche Bekanntmachung RegisSTAR</br></br></br></br>Amtsgericht Osnabrück Aktenzeichen: HRB 100678 </br>Bekannt gemacht am:
# <mark class="entity" style="background: #48bb96; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     04.05.2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PUBDATE</span>
# </mark>
#  17:03 Uhr</br></br>In () gesetzte Angaben der Anschrift und des Geschäftszweiges erfolgen ohne Gewähr.</br>Veränderungen</br>28.04.2009</br></br>H&amp;R Chemisch-Pharmazeutische Spezialitäten GmbH, Salzbergen, Neuenkirchener Straße 8, 48499 Salzbergen.Geschäftsanschrift: Neuenkirchener Straße 8, 48499 Salzbergen.
# <mark class="entity" style="background: #6c83f3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bestellt als
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">STATUS</span>
# </mark>
#
# <mark class="entity" style="background: #b33989; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geschäftsführer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# :
# <mark class="entity" style="background: #24bb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wendroth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SURNAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #81f1d0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gert
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# ,
# <mark class="entity" style="background: #7ed8d3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Großhansdorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# , *
# <mark class="entity" style="background: #d50c09; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     03.12.1958
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BIRTHDAY</span>
# </mark>
# , mit der Befugnis, im Namen der Gesellschaft mit sich im eigenen Namen oder als Vertreter eines Dritten Rechtsgeschäfte abzuschließen.</div></span>
